# %% [markdown]
# <a href="https://colab.research.google.com/github/ashwithareddykatta-code/sentiment-analysis-projects/blob/main/task_5_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import string
import random
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords

# Healthcare Knowledge Base
qa_pairs = {
    "what is fever": "Fever is a temporary increase in body temperature.",
    "symptoms of fever": "High temperature, sweating, chills, headache.",
    "treatment for fever": "Drink fluids, rest, and take paracetamol if needed.",
    "what is cold": "Common cold is a viral infection.",
    "symptoms of cold": "Runny nose, sneezing, sore throat.",
    "what is diabetes": "Diabetes is high blood sugar condition.",
    "what is headache": "Pain in head region.",
    "what is covid": "COVID-19 is a respiratory illness.",
    "how to stay healthy": "Eat well, exercise, sleep properly."
}

greetings = ["hi", "hello", "hey"]

# Preprocess function
def preprocess(text):
    words = word_tokenize(text.lower())
    words = [w for w in words if w not in string.punctuation]
    words = [w for w in words if w not in stopwords.words('english')]
    return set(words)

# Single question function (IMPORTANT FIX for Colab)
def get_response(user_input):

    if user_input in greetings:
        return random.choice(["Hello!", "Hi there!", "Hey!"])

    user_words = preprocess(user_input)

    best_match = None
    max_score = 0

    for question in qa_pairs:
        question_words = preprocess(question)
        score = len(user_words.intersection(question_words))

        if score > max_score:
            max_score = score
            best_match = question

    if best_match and max_score > 0:
        return qa_pairs[best_match]
    else:
        return "Please consult a doctor for proper advice."

# Test chatbot manually (NO LOOP - WORKS IN COLAB)
print("Type your question below:")

user_input = input()
print("Chatbot:", get_response(user_input))
# Out:
# Type your question below:
# what is fever
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# /tmp/ipykernel_2890/1258353455.py in <cell line: 0>()
#      54
#      55 user_input = input()
# ---> 56 print("Chatbot:", get_response(user_input))
#
# /tmp/ipykernel_2890/1258353455.py in get_response(user_input)
#      32         return random.choice(["Hello!", "Hi there!", "Hey!"])
#      33
# ---> 34     user_words = preprocess(user_input)
#      35
#      36     best_match = None
#
# /tmp/ipykernel_2890/1258353455.py in preprocess(text)
#      21 # Preprocess function
#      22 def preprocess(text):
# ---> 23     words = word_tokenize(text.lower())
#      24     words = [w for w in words if w not in string.punctuation]
#      25     words = [w for w in words if w not in stopwords.words('english')]
#
# ...
